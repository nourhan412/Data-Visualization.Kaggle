# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
dat=pd.read_csv("../input/spotify-top-100-songs-of-20152019/Spotify 2010 - 2019 Top 100.csv")
sns.lineplot(data=dat)
# Out:
# Setup Complete
# <AxesSubplot:>
